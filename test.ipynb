# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math as m
# %matplotlib inline

# %% [markdown]
# # Centrifugal Barrier of partial wave
# # ddi dipole-dipole interaction

# %%
# constant
mu_0 = 
epsilon_0 = 
cdd = mu_0 * mu ** 2

# %%
r = np.linspace(0, 100, 100)
ddi = cdd * (1 - 3 * np.cos(theta) ** 2) / (4 * m.pi * r ** 3)
